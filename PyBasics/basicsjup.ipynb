# %%
print("Heloo")
# Out:
# Heloo

# %%
#variables
x=2
print(x)
# Out:
# 2

# %%
x=2
y=3
print(x)
print(y)
# Out:
# 2
# 3

# %%
x=3
y="adil"
print(y)
print(x)
# Out:
# adil
# 3

# %%
x=34
y="adil"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
myvar="adil"
Myvar="adil"
my_var="adil"
My_var="adil"
print(myvar)
print(Myvar)
print(my_var)
print(My_var)
# Out:
# adil
# adil
# adil
# adil

# %%
x,y,z="shaik","mahammad","adil"
print(x)
print(y)
print(z)
# Out:
# shaik
# mahammad
# adil

# %%
name=["shaik","mahammad","adil"]
x,y,z=name
print(x)
print(y)
print(z)
# Out:
# shaik
# mahammad
# adil

# %%
x=y=z="banana"
print(x)
print(y)
print(z)
# Out:
# banana
# banana
# banana

# %%
x="shaik"
y="mahammad" 
z="adil"
print(x,y,z)
# Out:
# shaik mahammad adil

# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
x=10
y="adil"
print(x,y)
# Out:
# 10 adil

# %%
x = "awesome"

def myfunc():
    # x="adil"
    print("python is " +x)
myfunc()
# Out:
# python is awesome

# %%
x="awesome"
def func():
    x="fanstatic"
    print("python is "+x)
func()
print("python is "+x)
# Out:
# python is fanstatic
# python is awesome

# %%
def func():
    global x
    x='adil'
func()
print(x)
# Out:
# adil

# %%
x="adil"
def func():
    global x
    x="shaik"
func()
print(x)
# Out:
# shaik

# %%
import random
print(random.randrange(100,999))
# Out:
# 905
